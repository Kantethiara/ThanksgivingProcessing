# %% [markdown]
# # UCAD | FST | Dept MATHS-INFO | Master 1 MSI 2022-2023

# %% [markdown]
# ## Projet final : Cours Programmation en Python avec M. Ousmane Sy Bodian
#
# - **---> A Rendre le Mercredi 03 Mai 2023 à 17H00 en présentiel sous format
#   éléctronique (je viendrai les récupérer dans une clé USB)**
#
# ### Plan :
#
# *Ce projet comporte trois grandes parties :*
# - I°). Inspection (comprehension de la base de données **'Thanksgiving'**)
# >- Importation des librairies
# >- Prétraitement : Créer un dictionnaire qui va contenir
#    l'ensemble des noms de colonnes (variables) ainsi que leur position.
# >- Supprimer les Doublons s'il y'en a
# >- Imputation des données manquantes
# - II°). Analyse Univariée et Bivariée des données
# >- Tableaux de contingence
# >- Tests Statistiques
# >- Visualisation des données
# - III°). Analyse Avancée
# >- Utiliser des filtres et de selections dans les observations
# >- Utiliser des fonctions prédéfinies pour calculer et afficher des statistiques
# >- Utiliser nos propres fonctions et programmes pour calculer et afficher des statistiques
#
#
#
# ### -------------------------------------------- Méthode d'Evaluation -------------------------------------------------------
#
# **Dans cette section, nous vous expliquons comment faire et comment rendre ce projet :**
#
# - En effect vous utiliserez le fichier notebook nommé **NotebookProjetFinalPython.ipynb** se trouvant
#   dans le **Discord (Ressources)**.
# - Et donc sur ce Notebook, vous créerez à chaque fois que nécessaire une nouvelle cellule en dessous de chaque
#   Question (tache à faire) dans laquelle vous mettrez votre réponse.
# - Pour plus de transparance, vous débuterez chacune de vos réponses par le commentaire **#MaReponse**
#   dans toute cellule que vous vous créerez.
# - Au moment de rendre le projet, nous vous demandons d'exécuter toutes vos cellules qu'elles marchent ou pas
# - Au moment de rendre le projet, nous vous demandons de renommer le fichier Notebook par exemple comme suit :
#   **MadaniCamara_ProjetFinalPython.ipynb**
# - Quand vous aurez fini c'est à dire à la dateline (**Mercredi 03 Mai 2023 à 17H00**),
#   je viendrai récupérer tous les scripts ou   Notebook sur une Clé USB (nous vous
#   recommandons de venir avec vos ordinateurs).

# %% [markdown]
# # I°). Inspection (comprehension) de la base de données

# %% [markdown]
# ## I.0 Importation des librairies et du dataset

# %% [markdown]
# - Importer les librairies :
# >- pandas
# >- matplotlib.pyplot
# >- numpy
# >- seaborn
# - Utiliser la fonction pandas.read_csv() pour lire le fichier 'thanksgiving.csv'.
# >- Spécifier dans les paramètres de la fonction l'argument **encoding = 'latin-1'** car ce dataset n'est pas encodé normalement
# >- Assigner le dataframe à la variable data
# - Afficher les premières lignes de data.
# - Afficher le nom des colonnes avec l'attribut columns.

# %%
#Ma REPONSE
# 1. Importation de toutes les libraires requises dans cette application ----------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#MA REPONSE
#Importation du Dataset "thanksgiving.csv"
data = pd.read_csv("thanksgiving.csv",
                   encoding = "Latin-1")
#Afficher les 5premieres lignes de data
data.head()
#Afficher le nom des colonnes avec l'attribut columns
variable_names=data.columns.tolist()

# %% [markdown]
# ## I.1 Prétraitement des données

# %% [markdown]
# - Créer un dictionnaire qui va contenir l'ensemble des noms de colonnes (variables) ainsi que leur position.

# %%
#MA REPONSE
#Afficher la dimension du dataset
dimension=data.shape
print(dimension)
#Afficher le nombre de colonnes
n_colonne=dimension[1]
print(n_colonne)
# Out:
# (1058, 65)
# 65

# %%
#MA REPONSE
#creation d'une dictionnaire
variable_name_as_dict={} 
variable_name_as_dict.update(zip(variable_names,range(n_colonne)))
print(variable_name_as_dict)
# Out:
# {'RespondentID': 0, 'Do you celebrate Thanksgiving?': 1, 'What is typically the main dish at your Thanksgiving dinner?': 2, 'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)': 3, 'How is the main dish typically cooked?': 4, 'How is the main dish typically cooked? - Other (please specify)': 5, 'What kind of stuffing/dressing do you typically have?': 6, 'What kind of stuffing/dressing do you typically have? - Other (please specify)': 7, 'What type of cranberry saucedo you typically have?': 8, 'What type of cranberry saucedo you typically have? - Other (please specify)': 9, 'Do you typically have gravy?': 10, 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts': 11, 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots': 12, 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select al
# ...

# %%
#data.info()
#Création d'une fonction qui me permettra de convertir les types 'object' en 'category'
def variable_object(data) :
    for i in data.columns.tolist():
         
        if data[i].dtype == "object":
             data[i] = data[i].astype("category")           
        else :
            data[i].dtype 

    return data
#Appell
data = variable_object(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 65 columns):
#  #   Column                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                        --------------  -----
#  0   RespondentID                                                                                                                                  1058 non-null   int64
#  1   Do you celebrate Thanksgiving?                                                                                                                1058 non-null   category
#  2   What is typically the main dish at your Thanksgiving dinner?                                                                                  974 non-null    category
# ...

# %% [markdown]
# ## I.2 Vérification et Suppression des Doublons

# %% [markdown]
# Vérifier si le jeu de données présente des Doublons. Et si c'est le cas, Supprimer les du dataset.

# %%
#MA REPONSE
data.duplicated()
data.duplicated().sum()

#D'aprés les résultats, ce dataset ne présente pas de doublons
# Out:
# 0

# %% [markdown]
# #### MA REPONSE
# D'aprés les résultats, ce dataset ne présente pas de doublons

# %% [markdown]
# ## I.3 Imputation des données manquantes

# %% [markdown]
# - Ecrire un programme qui vous permettra d'Imputer toutes les données manquantes.

# %%
#MA REPONSE
#crer une fonction qui nous donne le % des valeus manquantes
def pourcen_na_values(data):
        return round(data.isnull().sum() / dimension[0] * 100, 2).sort_values(ascending = False).astype('str') + "%"
#appel
pourcen_na_values(data)
# Out:
# Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Blondies    98.49%
# What type of cranberry saucedo you typically have? - Other (please specify)                                         97.64%
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach            96.79%
# Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Buttermilk       96.69%
# What is typically the main dish at your Thanksgiving dinner? - Other (please specify)                               96.69%
#                                                                                                                      ...
# Age                                                                                                                  3.12%
# What is your gender?                                                                                                 3.12%
# ...

# %%
#MA REPONSE 
#Visualisation des valeurs manquantes à l'aide de la librairie 'missingno'
import missingno as mno
mno.bar(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### MA REPONSE
# **Commentaire :Le graphique de barres généré par mno.bar(data) montre la proportion de valeurs manquantes pour chaque attribut de l'ensemble de données data Plus la barre est faible, plus la proportion de données manquantes est faible pour cet attribut.**

# %% [markdown]
# **Imputation des données manquantes:
# Les deux méthodes les plus courantes pour l'imputation des données manquantes sont l'imputation par la médiane et l'imputation par le mode. On doit imputer par la médiane lorsque la variable est quantitative et que la distribution est asymétrique, c'est-à-dire lorsque la moyenne est sensible aux valeurs extrêmes. En imputant par la médiane, on évite que les valeurs extrêmes influencent trop la valeur de l'imputation.On utilise l'imputation par mode pour les variables qualitatives ou catégorielles. Le mode est la valeur la plus fréquente dans une distribution de données. Si une variable catégorielle contient des données manquantes, on peut remplacer ces valeurs manquantes par la valeur modale de la distribution des données non manquantes de cette variable. Cela permet de maintenir la distribution de la variable et de ne pas fausser les résultats.**

# %%
#Création d'une fonction pour imputer de valeurs manquante
def imputing_mising_values(data):
    for i in data.columns.tolist():
        if data[i].dtype == "category":
            data[i].fillna(data[i].value_counts().index[0], inplace = True)#inputer par le mode
        else :
            data[i].fillna(data[i].median(), inplace = True)#inputer par la mediane
    return  data
#Appell
data_imputing = imputing_mising_values(data)
data_imputing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 65 columns):
#  #   Column                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                        --------------  -----
#  0   RespondentID                                                                                                                                  1058 non-null   int64
#  1   Do you celebrate Thanksgiving?                                                                                                                1058 non-null   category
#  2   What is typically the main dish at your Thanksgiving dinner?                                                                                  1058 non-null   category
# ...

# %% [markdown]
# # II°). Analyse Univariée et Bivariée des données

# %% [markdown]
# ## II.0 Selection des variables à analyser

# %% [markdown]
# Dans un premier temps, nous allons faire un tri des variables sur lesquelles
# nous allons nous focaliser pour faire l'analyse univariée et bivariée des données.
#
# **Variables à analyser :**
# >- 'Do you celebrate Thanksgiving?' (**Variable Cible**)
# >- 'What is typically the main dish at your Thanksgiving dinner?'
# >- 'Do you typically have gravy?'
# >- 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'
# >- 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'
# >- 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'
# >- 'How far will you travel for Thanksgiving?'
# >- 'Age'
# >- 'What is your gender?'
# >- 'How much total combined money did all members of your HOUSEHOLD earn last year?'
# >- 'Have you ever tried to meet up with hometown friends on Thanksgiving night?'
# >- 'Have you ever attended a "Friendsgiving?"'

# %% [markdown]
# ## II.1 Analyse Univariée
#
# - Faites l'analyse univariée de l'ensemble des variables citées ci-dessus (**section 2.0**).

# %%
#MA REPONSE
#selectionner les variables à étudier dans cette partie et affecté le resultat dans 'data_analyse'
data_analyse = data_imputing.iloc[:,[1, 2, 10, 26, 34, 33, 52, 61, 62, 63, 55, 56]]
data_analyse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 12 columns):
#  #   Column                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                      --------------  -----
#  0   Do you celebrate Thanksgiving?                                                                              1058 non-null   category
#  1   What is typically the main dish at your Thanksgiving dinner?                                                1058 non-null   category
#  2   Do you typically have gravy?                                                                                1058 non-null   category
#  3   Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple    1058 non-null   category
# ...

# %% [markdown]
# #### MA REPONSE

# %%
# La fonction describe() nous fournit les statistiques de base de variables 
data_analyse.describe().T
# Out:
#                                                    count unique  \
# Do you celebrate Thanksgiving?                      1058      2
# What is typically the main dish at your Thanksg...  1058      8
# Do you typically have gravy?                        1058      2
# Which type of pie is typically served at your T...  1058      1
# Which type of pie is typically served at your T...  1058      1
# Which type of pie is typically served at your T...  1058      1
# How far will you travel for Thanksgiving?           1058      4
# Age                                                 1058      4
# What is your gender?                                1058      2
# How much total combined money did all members o...  1058     11
# Have you ever tried to meet up with hometown fr...  1058      2
# Have you ever attended a "Friendsgiving?"           1058      2
#
#                                                                                                   top  \
# ...

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,0], 'freq', normalize = True)*100
# Out:
# col_0                                freq
# Do you celebrate Thanksgiving?
# No                               7.372401
# Yes                             92.627599

# %% [markdown]
# **Commentaire : Les données montrent que les personnes célèbrant le "Thanksgiving" sont beaucoup plus nombreux que celles qui ne le célèbre pas.**

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,1], 'freq', normalize = True)*100
# Out:
# col_0                                                    freq
# What is typically the main dish at your Thanksg...
# Chicken                                              1.134216
# Ham/Pork                                             2.741021
# I don't know                                         0.472590
# Other (please specify)                               3.308129
# Roast beef                                           1.039698
# Tofurkey                                             1.890359
# Turducken                                            0.283554
# Turkey                                              89.130435

# %% [markdown]
# **Commentaire : les données montrent que parmis les plats principaux,les Dindes (Turkey) sont plus utilisés**

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,2], 'freq', normalize = True)*100
# Out:
# col_0                              freq
# Do you typically have gravy?
# No                             7.750473
# Yes                           92.249527

# %% [markdown]
# **Commentaire : les données montrent la majeure partie des personnes avait généralement de la sauce**

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,3], 'freq', normalize = True)*100
# Out:
# col_0                                                freq
# Which type of pie is typically served at your T...
# Apple                                               100.0

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,6], 'freq', normalize = True)*100
# Out:
# col_0                                                    freq
# How far will you travel for Thanksgiving?
# Thanksgiving is happening at my home--I won't t...  47.542533
# Thanksgiving is local--it will take place in th...  26.086957
# Thanksgiving is out of town and far away--I hav...   7.750473
# Thanksgiving is out of town but not too far--it...  18.620038

# %% [markdown]
# **Commentaire : Les données montrent que les gens ont tendance a célèbrer leur 'hanksgiving' chez eux**

# %%
#Les statistiques de la variables 'Age'
data_analyse.iloc[:,7].describe()
# Out:
# count        1058
# unique          4
# top       45 - 59
# freq          319
# Name: Age, dtype: object

# %% [markdown]
# **Commentaire : Les données montrent que la classe d'age la plus fréquente dans la célébration de 'hanksgiving'est de 45 à 59ans**

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,8], 'freq', normalize = True)*100
# Out:
# col_0                      freq
# What is your gender?
# Female                54.536862
# Male                  45.463138

# %% [markdown]
# **Commentaire : Les données montrent que la participation des femmes dans la célébration de'hanksgiving' est légèrement plus inportante que celle des hommes**

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,9], 'freq', normalize = True)*100
# Out:
# col_0                                                    freq
# How much total combined money did all members o...
# $0 to $9,999                                         6.238185
# $10,000 to $24,999                                   6.427221
# $100,000 to $124,999                                10.491493
# $125,000 to $149,999                                 4.631380
# $150,000 to $174,999                                 3.780718
# $175,000 to $199,999                                 2.551985
# $200,000 and up                                      7.561437
# $25,000 to $49,999                                  20.132325
# $50,000 to $74,999                                  12.759924
# $75,000 to $99,999                                  12.570888
# Prefer not to answer                                12.854442

# %% [markdown]
# **Commentaire : les données montrent qu'il beaucoup de ménages dont chaque membres gagne entre 25 000 et 49 999 Dollars.Cependant on a un pourcentage faible aux familles qui ont gagné entre 175 000 et 199 999 Dollars.**

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,10], 'freq', normalize = True)*100
# Out:
# col_0                                                    freq
# Have you ever tried to meet up with hometown fr...
# No                                                  66.257089
# Yes                                                 33.742911

# %% [markdown]
# **Commentaire : Les données montrent que la plus part des personnes n'ont pas essayé de rencontrer des amis de leur ville natale le soir de Thanksgiving .**

# %%
# Tableau des fréquences (en Poucentages)
pd.crosstab(data_analyse.iloc[:,11], 'freq', normalize = True)*100
# Out:
# col_0                                           freq
# Have you ever attended a "Friendsgiving?"
# No                                         74.669187
# Yes                                        25.330813

# %% [markdown]
# **Commentaire : Les données montrent que la plus part des personnes n'ont pas assisté a un "Friendsgiving".**

# %% [markdown]
# ## II.2 Analyse Bivariée
#
# - En considérant la variable **'Do you celebrate Thanksgiving?'** comme **cible** ou **dépendante**
# - En vous basant des **tableaux de contingence** étudier la dépendance notée entre chacune des variables
#   citées ci-dessus (**section 2.0**) par rapport à la variable considérée comme cible.
# - Chaque tableau doit s'accompagner d'un **test statistique** approprié.

# %% [markdown]
# #### MA REPONSE

# %%
import scipy.stats as sp
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et
#"What is typically the main dish at your Thanksgiving dinner?"
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,1])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (10.269288203086115,
#  0.1738198119915183,
#  7,
#  array([[8.84688091e-01, 2.13799622e+00, 3.68620038e-01, 2.58034026e+00,
#          8.10964083e-01, 1.47448015e+00, 2.21172023e-01, 6.95217391e+01],
#         [1.11153119e+01, 2.68620038e+01, 4.63137996e+00, 3.24196597e+01,
#          1.01890359e+01, 1.85255198e+01, 2.77882798e+00, 8.73478261e+02]]))

# %% [markdown]
# **Commentaire : La p-value = 0.17 > 0.05 = 5%, donc on accept l'hypothése nulle (𝐻0) d'independence.
# Autrement, sur nos données le fait de célébrer ou non le Thanksgiving est indépendant du plat principal du dîner de Thanksgiving .**

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"Do you typically have gravy?"
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,2])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (5.95296728280169,
#  0.014692534237270795,
#  1,
#  array([[  6.04536862,  71.95463138],
#         [ 75.95463138, 904.04536862]]))

# %% [markdown]
# **Commentaire : La p-value = 0.01 < 0.05 = 5%, donc on rejette l'hypothése nulle (𝐻0) d'independence.
# Autrement, sur nos données le fait de célébrer oui ou non le Thanksgiving est dépendant du fait d'avoir généralement de la sauce.**

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple"
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,3])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (0.0,
#  1.0,
#  0,
#  array([[ 78.],
#         [980.]]))

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin"
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,4])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (0.0,
#  1.0,
#  0,
#  array([[ 78.],
#         [980.]]))

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan"
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,5])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (0.0,
#  1.0,
#  0,
#  array([[ 78.],
#         [980.]]))

# %% [markdown]
# **Commentaire : D'aprés les résultats le fait de célébrer ou non le Thanksgiving est indépendant du type de tarte servi pour le dinner .**

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"How far will you travel for Thanksgiving?":
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,6])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (92.91357974601372,
#  5.183858329708202e-20,
#  3,
#  array([[ 37.0831758 ,  20.34782609,   6.04536862,  14.52362949],
#         [465.9168242 , 255.65217391,  75.95463138, 182.47637051]]))

# %% [markdown]
# **Commentaire : La p-value = 5.18e-20 < 0.05 = 5%, donc on rejette l'hypothése nulle (𝐻0) d'independence. Autrement, sur nos données le fait de célébrer ou non le Thanksgiving est dépendant de la distance faite pour assister à la célébration .**

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et "Age" 
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,7])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (28.77280143529557,
#  2.4996109725513077e-06,
#  3,
#  array([[ 15.92438563,  19.09451796,  23.51795841,  19.463138  ],
#         [200.07561437, 239.90548204, 295.48204159, 244.536862  ]]))

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"What is your gender?"
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,8])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (9.490465383274914,
#  0.002065424241320496,
#  1,
#  array([[ 42.53875236,  35.46124764],
#         [534.46124764, 445.53875236]]))

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"How much total combined money did all members of your HOUSEHOLD earn last year?"
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,9])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (38.09079109505197,
#  3.659508140948948e-05,
#  10,
#  array([[  4.8657845 ,   5.01323251,   8.18336484,   3.61247637,
#            2.9489603 ,   1.9905482 ,   5.8979206 ,  15.70321361,
#            9.95274102,   9.80529301,  10.02646503],
#         [ 61.1342155 ,  62.98676749, 102.81663516,  45.38752363,
#           37.0510397 ,  25.0094518 ,  74.1020794 , 197.29678639,
#          125.04725898, 123.19470699, 125.97353497]]))

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"Have you ever tried to meet up with hometown friends on Thanksgiving night?"
#Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,10])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (41.27097800614291,
#  1.3252193884290707e-10,
#  1,
#  array([[ 51.6805293,  26.3194707],
#         [649.3194707, 330.6805293]]))

# %%
#Etude de dépendance entre les variables "Do you celebrate Thanksgiving?" et 
#"Have you ever attended a "Friendsgiving?""
# Tableau de contingence
tab = pd.crosstab(data_analyse.iloc[:,0], data_analyse.iloc[:,11])

# Test de Chi2 
sp.chi2_contingency(tab)
#Affichage du tableau de contingrnce
#tab
# Out:
# (27.13928106830373,
#  1.8931193345482537e-07,
#  1,
#  array([[ 58.24196597,  19.75803403],
#         [731.75803403, 248.24196597]]))

# %% [markdown]
# **Commentaire :  Ces cinq derniers tests montrent que les résultats sont statistiquement significatifs(p-value < 0.05 = 5%) et que l'hypothèse nulle peut être rejetée.En effet on a une dépendance entre le fait de célebrer ou non le Thanksgiving et les variables étudiées précédement.**

# %% [markdown]
# ## II.3 Visualisation des données
#
# - En considérant la variable **'Do you celebrate Thanksgiving?'** comme **cible** ou **dépendante**
# - Utiliser cette fois-ci des **Graphiques ou Diagrammes** pour étudier la dépendance notée entre chacune des variables
#   citées ci-dessus (**section 2.0**) par rapport à la variable considérée comme cible.

# %% [markdown]
# #### MA REPONSE

# %%
#Visualisation de la variables 'Do you celebrate Thanksgiving?'
# création des données
data = data_analyse['Do you celebrate Thanksgiving?'].value_counts()

# création des labels
labels = ['Yes', 'No']

# création du diagramme en secteurs
fig, ax = plt.subplots()
ax.axis('equal')  # rend les secteurs circulaires

# affichage du titre
plt.title('Répartition des personnes ayant célébré Thanksgiving')

# affichage du diagramme
ax.pie(data, labels=labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **Commentaire : ce diagramme représente les personnes ayant célébré ou non le Thanksgiving,on constate que la proportion des répondants ayant fait la célébration est plus importante que ceux qui l'ont pas célébré.**

# %%
fig = plt.figure(figsize = (15,6))
#sub plot
plt.subplot(1,2,1)
sns.countplot(x = "Do you typically have gravy?", 
              hue = "Do you celebrate Thanksgiving?",data = data_analyse)
plt.xticks(rotation = 90)      # rotation de l'étiquette de l'axe des x    
plt.legend(loc = 'upper left')   # affichage de la légende des courbes
plt.title("Evolution")
plt.xlabel('')
plt.ylabel("Fréquences")
plt.show()

# %% [markdown]
# **Commentaire : Le graphique représente le répartition des personnes qui ont généralement de la sauce en fonction de leur célébration ou non du Thanksgiving.On constate que Les personnes qui célèbrent Thanksgiving ont une proportion plus élevée de répondants qui déclarent généralement avoir de la sauce par rapport à ceux qui ne célèbrent pas.**

# %%
sns.countplot(x = "How far will you travel for Thanksgiving?", 
              hue = "Do you celebrate Thanksgiving?",data = data_analyse,palette = "cool")
plt.xticks(rotation = 90)      # rotation de l'étiquette de l'axe des x    
plt.legend(loc = 'upper right')   # affichage de la légende des courbes
plt.title("Evolution")
plt.xlabel('')
plt.ylabel("Fréquences")
plt.show()

# %% [markdown]
# **Commentaire : Le graphique représente la distribution de la variable "How far will you travel for Thanksgiving?" selon les réponses à la question "Do you celebrate Thanksgiving?". On peut observer que la majorité des personnes qui célèbrent Thanksgiving ne voyagent pas du tout, ce qui est cohérent avec la modalité "Thanksgiving is happening at my home--I won't travel at all" qui est la plus représentée. Pour ceux qui voyagent, la plupart se déplacent à une distance relativement proche, avec la modalité "Thanksgiving is local--it will take place in the town I live in" représentant la deuxième modalité la plus fréquente. La modalité "Thanksgiving is out of town and far away--I have to drive several hours or fly" est la moins fréquente, indiquant que la plupart des gens ne se déplacent pas sur de longues distances pour célébrer Thanksgiving.**

# %%
# création du diagramme en barres empilées
sns.catplot(x="What is your gender?", hue="Do you celebrate Thanksgiving?", kind='count', palette = "pink",data=data_analyse)

# affichage du titre
plt.title('Répartition des personnes ayant célébré Thanksgiving par genre')

# affichage du diagramme
plt.show()

# %% [markdown]
# **Commentaire : Ce diagramme est une représentation de la répartition des personnes ayant célébré Thanksgiving par genre.On peut observer que la proportion de femmes ayant célébré Thanksgiving est légèrement plus élevée que celle des hommes.**

# %%
# création du diagramme en barres empilées
sns.catplot(x="Age", hue="Do you celebrate Thanksgiving?", kind='count', palette = "PuRd",data=data_analyse)

# affichage du titre
plt.title('Répartition des Ages selon la célébration du Thanksgiving ')

# affichage du diagramme
plt.show()

# %% [markdown]
# **Commentaire : Ce graphique à barres empilées permet de visualiser la répartition des âges en fonction de la célébration de Thanksgiving. Les barres empilées représentent les différents groupes d'âge, tandis que les couleurs des barres représentent si la personne célèbre Thanksgiving ou non. La majorité des répondants se situent dans la tranche d'âge de 45 à 59 ans et la plupart d'entre eux célèbrent Thanksgiving. Il y a une diminution de la proportion de personnes célébrant Thanksgiving chez les plus jeunes de 18 à 29 ans et 30 à 44ans.**

# %%
fig = plt.figure(figsize = (15,19))

categorical_variable = [
'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple',
'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin',
'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan']
for i in range(len(categorical_variable)) :
    plt.subplot(3, 3, i+1)
    sns.countplot(x=categorical_variable[i], hue="Do you celebrate Thanksgiving?",
                  palette = "Blues", data = data_analyse)
    plt.xticks(rotation = 45)      # rotation de l'étiquette de l'axe des x    
    plt.legend(loc = 'upper right')   # affichage de la légende des courbes
    plt.title("Evolution")
    plt.xlabel('')
    plt.ylabel("Fréquences")   
    plt.show()

# %%
sns.countplot(x = "Have you ever tried to meet up with hometown friends on Thanksgiving night?", 
              hue = "Do you celebrate Thanksgiving?",data = data_analyse,palette = "Wistia")
plt.xticks(rotation = 90)      # rotation de l'étiquette de l'axe des x    
plt.legend(loc = 'upper right')   # affichage de la légende des courbes
plt.title("Evolution")
plt.xlabel('')
plt.ylabel("Fréquences")
plt.show()

# %% [markdown]
# **Commentaire : Ce graphique montre la distribution des réponses à la question "Avez-vous déjà essayé de retrouver des amis de votre ville natale le soir de Thanksgiving ?" en fonction de la variable "Do you celebrate Thanksgiving ?". Les barres représentent le nombre de personnes ayant répondu "oui" ou "non" à cette question, avec la couleur indiquant si elles célèbrent ou non Thanksgiving. On peut voir que la majorité des personnes qui célèbrent Thanksgiving ont répondu "non" à cette question. Cela peut indiquer que pour les personnes qui célèbrent Thanksgiving, la soirée est souvent consacrée à des activités familiales plutôt qu'à retrouver des amis de leur ville natale.**

# %%
sns.countplot(x = "How much total combined money did all members of your HOUSEHOLD earn last year?", 
              hue = "Do you celebrate Thanksgiving?",data = data_analyse,palette = "GnBu")
plt.xticks(rotation = 90)      # rotation de l'étiquette de l'axe des x    
plt.legend(loc = 'upper right')   # affichage de la légende des courbes
plt.title("Distribution du montant total gagné par les familles en fontion la célébration du Thanksgiving ")
plt.xlabel('')
plt.ylabel("Fréquences")
plt.show()

# %% [markdown]
# **Commentaire : Le graphique représente la distribution du montant total d'argent gagné par tous les membres du ménage l'année dernière, en fonction de la variable "Do you celebrate Thanksgiving?".Le graphes montrent que la célébration du Thanksgiving est plus fréquent chez les ménages ou chaque membres a un revenu entre 25 000 et 49 999 Dollars.**

# %%
sns.countplot(x = 'Have you ever attended a "Friendsgiving?"', 
              hue = "Do you celebrate Thanksgiving?",data = data_analyse,palette = "cool")
plt.xticks(rotation = 90)      # rotation de l'étiquette de l'axe des x    
plt.legend(loc = 'upper right')   # affichage de la légende des courbes
plt.title("Evolution")
plt.xlabel('')
plt.ylabel("Fréquences")
plt.show()

# %% [markdown]
# **Commentaire : Le graphique montre que la plus part des personnes ayant célébré le Thanksgiving n'ont jamais assisté à un "Friendsgiving".**

# %% [markdown]
# ## II.4 Conclusion :
#
# - En vous basant des statistiques notées à travers vos **tableaux de contingence**, **Graphiques visuels** et
#   **test statistique**, rédiger un mini rapport résumant toutes les dépendances observées entre la variable cible et
#   chacune des autres variables citées ci-dessus (**section 2.0**).

# %% [markdown]
# #### MA REPONSE
# - Après avoir analysé les tableaux de contingence, les graphiques visuels et les tests statistiques, plusieurs dépendances ont été observées entre la variable cible "Do you celebrate Thanksgiving?"et chacune des autres variables citées dans la section 2.0.
#
# Tout d'abord, nous avons constaté que l'âge est une variable importante, car les répondants âgés de 45 à 59 ans ont été les plus nombreux à célébrer Thanksgiving.
# Ensuite, nous avons observé que le revenu du ménage a également un impact significatif sur la célébration de Thanksgiving. Les répondants ayant un revenu compris entre 25 000  et 49 999 dollars étaient les plus susceptibles de célébrer Thanksgiving, tandis que ceux ayant un revenu de 200 000 $ ou plus étaient moins susceptibles de célébrer Thanksgiving.
# Avoir généralement de la sauce est un facteurs sgnificatif pour la célébration du Thanksgiving ,car les résultat nous ont montré que les personnes qui célèbrent Thanksgiving ont une proportion plus élevée de répondants qui déclarent généralement avoir de la sauce par rapport à ceux qui ne célèbrent pas.
# En ce qui concerne le genre, nous avons constaté que les femmes étaient plus susceptibles de célébrer Thanksgiving que les hommes.
# les personnes qui célèbrent Thanksgiving, la soirée est souvent consacrée à des activités familiales plutôt qu'à retrouver des amis de leur ville natale.
# Enfin, nous avons constaté que les répondants qui ont déjà assisté à un "Friendsgiving" étaient moins susceptibles de célébrer Thanksgiving à la maison avec leur famille.
#
# En somme, cette étude a permis de mettre en évidence plusieurs dépendances significatives entre les variables étudiées et la célébration de Thanksgiving, offrant ainsi une meilleure compréhension de cette fête emblématique aux États-Unis.

# %% [markdown]
# # III°). Analyse Avancée

# %% [markdown]
# ## III.1 Filtrer des données

# %% [markdown]
# - Utiliser la méthode Series.value_counts() pour afficher le décompte du nombre de réponses pour chaque catégorie de la colonne 'Do you celebrate Thanksgiving?'.
# - Filtrer et garder toutes les lignes du dataframe data pour lesquelles la réponse à la question 'Do you celebrate Thanksgiving?' est 'Yes'.
# - Assigner ce nouveau dataframe à data et afficher le.

# %% [markdown]
# **MA REPONSE**

# %%
#2eme Importation du Dataset "thanksgiving.csv"
data = pd.read_csv("thanksgiving.csv",
                   encoding = "Latin-1")
#Afficher les 5premieres lignes de data
data.head()
#Afficher le nom des colonnes avec l'attribut columns
variable_names=data.columns.tolist()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 65 columns):
#  #   Column                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                        --------------  -----
#  0   RespondentID                                                                                                                                  1058 non-null   int64
#  1   Do you celebrate Thanksgiving?                                                                                                                1058 non-null   object
#  2   What is typically the main dish at your Thanksgiving dinner?                                                                                  974 non-null    object
# ...

# %%
#Utiliser la méthode Series.value_counts() pour afficher le décompte..
data.iloc[:,1].value_counts()
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
is_yes = (data["Do you celebrate Thanksgiving?"] == "Yes")
yes_answer = data[is_yes]
yes_answer
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %% [markdown]
# ## III.2 Exploration des repas de thanksgiving

# %% [markdown]
# - Utiliser la méthode Series.value_counts() pour afficher combien de fois chaque résultat apparaît pour la question et colonne 'What is typically the main dish at your Thanksgiving dinner?'.
# - Afficher la colonne 'Do you typically have gravy?' pour les lignes du dataframe data pour lesquelles la colonne 'What is typically the main dish at your Thanksgiving dinner?' vaut 'Tofurkey' pour la dinde de tofu.
# >- Créer un filtre qui sélectionne seulement les lignes du dataframe data où 'What is typically the main dish at your Thanksgiving dinner?' vaut 'Tofurkey'
# >- Assigner le résultat à la variable tofurkey
# >- Afficher la colonne 'Do you typically have gravy?' de ce nouveau dataframe tofurkey

# %% [markdown]
# **MA REPONSE**

# %%
#Utiliser la méthode Series.value_counts() pour afficher combien de fois chaque résultat...
data.iloc[:,2].value_counts()
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
#Afficher la colonne 'Do you typically have gravy?' pour les lignes du dataframe...
gravy_Tofurkey=data.iloc[:,[2,10]]
ans_gravy_Tofurkey=gravy_Tofurkey[gravy_Tofurkey.iloc[:,0]=='Tofurkey']
ans_gravy=ans_gravy_Tofurkey.iloc[:,1]
ans_gravy
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
#Créer un filtre qui sélectionne seulement les lignes du dataframe data où 'What is typically...
filtre = (data["What is typically the main dish at your Thanksgiving dinner?"] == "Tofurkey")
data_filtre = data[filtre]
data_filtre
# Out:
#      RespondentID Do you celebrate Thanksgiving?  \
# 4      4337931983                            Yes
# 33     4337771439                            Yes
# 69     4337553422                            Yes
# 72     4337540484                            Yes
# 77     4337490067                            Yes
# 145    4337191550                            Yes
# 175    4337139327                            Yes
# 218    4337078951                            Yes
# 243    4337044348                            Yes
# 275    4336997445                            Yes
# 393    4336894719                            Yes
# 399    4336891075                            Yes
# 571    4336760110                            Yes
# 594    4336736562                            Yes
# 628    4336692873                            Yes
# 774    4336400854                            Yes
# 820    4336238126                            Yes
# 837    4336175740                            Yes
# ...

# %%
#Afficher la colonne 'Do you typically have gravy?' de ce nouveau dataframe tofurkey
have_gravy_Tofurkey = data_filtre.iloc[:,10]
have_gravy_Tofurkey
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %% [markdown]
# ## III.3 Tendances des desserts pour Thanksgiving

# %% [markdown]
# - Créer un objet Series indiquant avec des booléens les valeurs de la colonne 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple' qui sont nulles. Assigner le résultat à la variable apple_isnull.
# - Créer un objet Series indiquant avec des booléens les valeurs de la colonne 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin' qui sont nulles. Assigner le résultat à la variable pumpkin_isnull.
# - Créer un objet Series indiquant avec des booléens les valeurs de la colonne 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan' qui sont nulles. Assigner le résultat à la variable pecan_isnull.
# - Combiner ces 3 objets Series avec l'opérateur & et assigner le résultat à la variable pies.
# - Afficher les valeurs uniques et combien de fois elles apparaissent dans la colonne de pies.

# %% [markdown]
# **MA REPONSE**

# %%
Apple_isnull=pd.isnull(data.iloc[:,26])
Apple_isnull
pumpkin_isnull=pd.isnull(data.iloc[:,34])
pumpkin_isnull
pecan_isnull=pd.isnull(data.iloc[:,3])
pecan_isnull
#Combiner ces 3 objets Series avec l'opérateur & et assigner le résultat à la variable pies.
pies = Apple_isnull & pumpkin_isnull & pecan_isnull
pies.value_counts()
# Out:
# False    844
# True     214
# dtype: int64

# %% [markdown]
# ## III.4 Convertir l'âge en une valeur numérique

# %% [markdown]
# - Ecrire une fonction qui convertit une chaine de caractères en une valeur entière. Cela permettra de convertir les valeurs de la colonne 'Age' en entiers. Cette fonction prendra en paramètre une chaine de caractères (les valeurs actuelles de la colonne 'Age')
# >- Utiliser la fonction isnull() pour vérifier si les valeurs sont nulles. Ajouter une condition if qui retourne 'None' si la valeur est nulle
# >- Séparer les chaines de caractères en fonction de l'espace (' ') et extraire le premier élément de la liste résultante (méthode split())
# >- Remplacer le caractère '+' dans le résultat avec une chaine de caractères vide en remplacement pour le supprimer (méthode replace())
# >- utiliser int() pour convertir le résultat en entier
# >- Retourner le résultat
# - Utiliser la méthode Series.apply() pour appliquer la fonction à chaque valeur de la colonne 'Age' du dataframe data.
# >- Assigner le résultat à la nouvelle colonne int_age du dataframe data
# - Appeler la méthode Series.describe() sur la colonne 'int_age' du dataframe data et afficher le résultat.

# %% [markdown]
# **MA REPONSE**

# %%
def convert_age(age_str):
    if pd.isnull(age_str):
        return None
    else:
        age = age_str.split(' ')[0]
        age = age.replace('+', '')
        return int(age)
#Utiliser la méthode Series.apply() pour appliquer la fonction à chaque valeur de la colonne...
data['int_age'] = data['Age'].apply(convert_age)
print(data["int_age"])
#Appeler la méthode Series.describe() sur la colonne 'int_age' du dataframe data ...
data["int_age"].describe().round()
# Out:
# 0       18.0
# 1       18.0
# 2       18.0
# 3       30.0
# 4       30.0
#         ...
# 1053    30.0
# 1054    60.0
# 1055    60.0
# 1056     NaN
# 1057     NaN
# Name: int_age, Length: 1058, dtype: float64
# count    1025.0
# mean       39.0
# std        15.0
# min        18.0
# 25%        30.0
# 50%        45.0
# 75%        60.0
# max        60.0
# Name: int_age, dtype: float64

# %% [markdown]
# ## III.5 Convertir les revenus en valeurs numériques

# %% [markdown]
# - Ecrire une fonction pour convertir les revenus en valeur unique de format entier.
# >- Utiliser la fonction isnull() pour vérifier si la valeur est nulle. Si c'est le cas, retourner 'None'
# >- Séparer la chaine de caractères en prenant l'espace comme délimiteur et extraire le premier élément de la liste résultante
# >- Si le résultat vaut 'Prefer', retourner 'none'
# >- Remplacer les caractères '$' et ',' par des chaines de caractères vides pour les supprimer
# >- Utiliser int() pour convertir le résultat en entier
# >- Retourner le résultat
# - Utiliser la méthode Series.apply() pour appliquer la fonction précédente à chaque valeur de la colonne 'How much total combined money did all members of your HOUSEHOLD earn last year?' du dataframe data.
# >- Assigner le résultat à la nouvelle colonne 'int_income' du dataframe data
# - Appeler la méthode Series.describe() à la colonne int_income du dataframe data et afficher le résultat.

# %% [markdown]
# **MA REPONSE**

# %%
def convert_income(income_str):
    if pd.isnull(income_str):
        return None
    income_str = income_str.split()[0]
    if income_str == "Prefer":
        return None
    income_str = income_str.replace('$', '').replace(',', '')
    return int(income_str)
#Appell
data['int_income'] = data['How much total combined money did all members of your HOUSEHOLD earn last year?'].apply(convert_income)
print(data['int_income'])
data['int_income'].describe().round()
# Out:
# 0        75000.0
# 1        50000.0
# 2            0.0
# 3       200000.0
# 4       100000.0
#           ...
# 1053    100000.0
# 1054     50000.0
# 1055    100000.0
# 1056         NaN
# 1057         NaN
# Name: int_income, Length: 1058, dtype: float64
# count       889.0
# mean      74078.0
# std       59361.0
# min           0.0
# 25%       25000.0
# 50%       50000.0
# 75%      100000.0
# max      200000.0
# Name: int_income, dtype: float64

# %% [markdown]
# ## III.6 Corrélation entre distance et revenus

# %% [markdown]
# - Regarder de quelle manière les personnes gagnant moins de 150000 dollars voyagent.
# >- Filtrer data en sélectionnant seulement les valeurs de 'int_income' inférieures à 150000
# >- Sélectionner la colonne 'How far will you travel for Thanksgiving?' en prenant en compte le filtre
# >- Utiliser la méthode value_counts() pour compter combien de fois chaque valeur apparaît dans la colonne
# >- Afficher les résultats
# - Faire de même avec les personnes gagnant plus de 150000 dollars.

# %% [markdown]
# **Ma reponse**

# %%
#Filtrer data en sélectionnant seulement les valeurs de 'int_income' inférieures à 150000
income_inf_150000=data[data.loc[:,'int_income']<150000]
#print(income_inf_15000)
#Sélectionner la colonne 'How far will you travel for Thanksgiving?' en prenant en compte le filtre
distanc_income_inf_150000=income_inf_150000.loc[:,'How far will you travel for Thanksgiving?']
#print(distanc_income_inf_150000)
#Utiliser la méthode value_counts() pour compter combien de fois chaque valeur...
distanc_income_inf_150000.value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %%
#Faire de même avec les personnes gagnant plus de 150000 dollars

#Filtrer data en sélectionnant seulement les valeurs de 'int_income' supérieures à 150000
income_sup_150000=data[data.loc[:,'int_income']>150000]
#print(income_sup_15000)
#Sélectionner la colonne 'How far will you travel for Thanksgiving?' en prenant en compte le filtre
distanc_income_sup_150000=income_sup_150000.loc[:,'How far will you travel for Thanksgiving?']
#print(distanc_income_sup_150000)
#Utiliser la méthode value_counts() pour compter combien de fois chaque valeur...
distanc_income_sup_150000.value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         49
# Thanksgiving is local--it will take place in the town I live in                     25
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    16
# Thanksgiving is out of town and far away--I have to drive several hours or fly      12
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# ## III.7 Lien entre passer Thanksgiving entre amis avec l'âge et le revenu

# %% [markdown]
# - Générer un pivot de table montrant la moyenne d'âge des sondés pour chaque catégorie des questions 'Have you ever tried to meet up with hometown friends on Thanksgiving night?' et 'Have you ever attended a "Friendsgiving?"'.
# >- Appeler la méthode pivot_table() sur le dataframe data
# >- Passer au paramètre 'index' la valeur 'Have you ever tried to meet up with hometown friends on Thanksgiving night?'
# >- Passer au paramètre 'columns' la valeur 'Have you ever attended a "Friendsgiving?"'
# >- Passer au paramètre 'values' la valeur 'int_age'
# >- Afficher les résultats
# - Faire de même pour les revenues avec ces 2 questions.

# %% [markdown]
# **MA REPONSE**

# %%
#Générer un pivot de table montrant la moyenne d'âge des sondés pour chaque catégorie ...
pivot_age = data.pivot_table(index='Have you ever tried to meet up with hometown friends on Thanksgiving night?',
    columns='Have you ever attended a "Friendsgiving?"',
    values='int_age')
#Afficher le resultat
pivot_age.round()
# Out:
# Have you ever attended a "Friendsgiving?"             No   Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  42.0  37.0
# Yes                                                 41.0  34.0

# %%
#Faire de même pour les revenues avec ces 2 questions
#Générer un pivot de table montrant la moyenne du revenu des sondés pour chaque catégorie ...
pivot_income = data.pivot_table(index='Have you ever tried to meet up with hometown friends on Thanksgiving night?',
    columns='Have you ever attended a "Friendsgiving?"',
    values='int_income')
#Afficher le resultat
pivot_income.round()
# Out:
# Have you ever attended a "Friendsgiving?"                No      Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  78915.0  72895.0
# Yes                                                 78750.0  66020.0

# %% [markdown]
# - **---> A Rendre le Vendredi 24 Juin 2022 à 17H00 en présentiel sous format
#   éléctronique (je viendrai les récupérer dans une clé USB)**
